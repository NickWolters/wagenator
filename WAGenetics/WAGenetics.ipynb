# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Sep 20 16:09:54 2024

@author: Nick.Wolters
"""
import grape
import algorithms

from os import path
import pandas as pd
import numpy as np
from deap import creator, base, tools
import random

GRAMMAR_FILE = 'wag.bnf'
BNF_GRAMMAR = grape.Grammar(r"grammars/" + GRAMMAR_FILE)

RANDOM_SEED = 42

toolbox = base.Toolbox()

# define a single objective, minimising fitness strategy:
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create('Individual', grape.Individual, fitness=creator.FitnessMin)

#toolbox.register("populationCreator", grape.sensible_initialisation, creator.Individual) 
toolbox.register("populationCreator", grape.random_initialisation, creator.Individual) 
#toolbox.register("populationCreator", grape.PI_Grow, creator.Individual) 

#toolbox.register("evaluate", fitness_eval)

# Tournament selection:
toolbox.register("select", tools.selTournament, tournsize=7) #selLexicaseFilter

# Single-point crossover:
toolbox.register("mate", grape.crossover_onepoint)

# Flip-int mutation:
toolbox.register("mutate", grape.mutation_int_flip_per_codon)

POPULATION_SIZE = 60
MAX_INIT_TREE_DEPTH = 50
MIN_INIT_TREE_DEPTH = 4

MAX_GENERATIONS = 200
P_CROSSOVER = 0.8
P_MUTATION = 0.1

MIN_INIT_GENOME_LENGTH = 95*6
MAX_INIT_GENOME_LENGTH = 115*6

random_initilisation = False #put True if you use random initialisation

CODON_CONSUMPTION = 'lazy'
GENOME_REPRESENTATION = 'list'
MAX_GENOME_LENGTH = None#'auto'

MAX_TREE_DEPTH = 40 #equivalent to 17 in GP with this grammar
MAX_WRAPS = 0
CODON_SIZE = 255

random.seed(RANDOM_SEED) 

population = toolbox.populationCreator(pop_size=POPULATION_SIZE, 
                                       bnf_grammar=BNF_GRAMMAR, 
                                       max_init_depth=MAX_INIT_TREE_DEPTH,
                                       codon_size=CODON_SIZE,
                                       codon_consumption=CODON_CONSUMPTION,
                                       genome_representation=GENOME_REPRESENTATION,
                                       min_init_genome_length= MIN_INIT_GENOME_LENGTH,
                                       max_init_genome_length= MAX_INIT_GENOME_LENGTH)

for i in range(POPULATION_SIZE):
    generated_grammar = population[i].phenotype
    formatted_generated_grammar = generated_grammar.replace(";", ";\n").replace("****", "****\n")
    
    print("-----")
    print(formatted_generated_grammar)
    print("-----\n\n")
# Out:
# -----
# KAIP4 -> ([&m1 = -26 <= 1 + 0 + 0.0] m)~ # [0.2] 365 # -79.4 # 1 # [0.6] u # g <*YGS7 = true>;
#
# -----
#
#
# -----
# r1:YrI8;
# ****
# w4 -> p # BWt;
#
# -----
#
#
# -----
# fArU:Q;
# ****
# i<*B> -> ("w")?;
#
# -----
#
#
# -----
# W<&d, &f, &g2, &q, *c> -> [$BuB2 = U] hq3;
#
# -----
#
#
# -----
# X:bLRAz;
# ****
# k -> (gu)@ # ([*A] -5.8)@ # (tA <$S = if !true then false>)@ # [$o = 9] false # ([*y7] S <$T = G>)~ # [0.9] -80.36 # a <*obsC = if !true then 0 <= 0> # (-7.1)@ # (Zc5 <$A9 = if false && 0.22 < -26 + 6 * 0 && true && !true then false>)@ # ([*A] BG4 <$WDa = if 5.8415 != 1.6 // -8 >= 0.3343 + -77.0 && 4 + -3 * 0.30 - 0.573 - 0.95 != 3.0 - -2 + 0.613 * 33 - 0 * -5.4 && 920 != -8 // 4 != 0 / -2.7 && 0 % -0.13 == 0 % -5 * 4.126 + 0 % -5.43 && false then -24.0 != 0.9 - 1.9 % 75.0 + 7.6 // !false>)~ # ([*u] n)@ # (e)? # ([*xU9] true)@ # [0.5] J <&EM = "o">;
#  c<&sv, *a> -> 1 # (o)? # [*y] "<Letter><Character>" # <Chunks>;
#
# -----
#
#
# -----
# h<*Q7> -> ([$S = 2.2 - 7 > -428 - 0] 7)@ # Xfu # ("FLh")?;
#  PEZ -> b4;
#
# -----
#
#
# -----
# jUV:tA6;
# e:J1;
# ****
# c -> (xN)?;
#
# -----
#
#
# -----
# V8 -> [*vRe] M # ([0.7] l6)?;
#
# -----
#
#
# -----
# u -> [*I] 0 # [*X] true # ([0.1] "ZO")~;
#  bK -> [0.3] false;
#  v5 -> (K7)@;
#
# -----
#
#
# -----
# A::p;
# ip2::a;
# ::fU;
# ****
# iSS<*D3> -> g <$o = 71.624 <= 3.675>;
#  Ttg<&PT, &Tz, &j, &nrX, *Z2> -> [&H1 = 9.6 + 0.0 / 0.2 <= -52.4360] 0 # ([*J] qs)@ # ([0.2] K <$G6 = 4>)? # [*JTVz1 = if 0.30 + 0 % 7.7 * 7.9 > 4.0 - 0.3 % 0.3 / -0.5 % 5.9 * -2.8 // 3 == 0.5 + 0.0 * 0.20 % 0 / -4 / 5.2 // 4 == 0 * 6.0 * -8 then 3 % -1.220 == 0 * 7197 + -7 * -9 / -5 / 3 / 0 / -0.16 + -30 && true && -6.3 % -0 - -8.0 == 1.0] -73.79 # Y3 <$NW4 = false>;
#
# -----
#
#
# -----
# S::o;
# Rqt:yQ;
# ****
# QA<&phOz, *hH> -> (T2)~ # cOH # (Lx <$pl = true>)? # ([$ZL5 = "jH"] IA)~;
#
# -----
#
#
# -----
# K3<*uXm4> -> b;
#
# -----
#
#
# -----
# KWZ:WN;
# ****
# T -> [$GL = "cqQ"] "e1";
#  L -> "a4";
#  GYr -> ([*z3 = 0 != -65.0] JCL <&CJ = -70.5>)@;
#  i4 -> [*Y] Q # [0.4] V <$P = false> # [0.8] j8 # ([0.6] "MmU")? # ("U1")~ # ([&h = 9] MkQ)~;
#
# -----
#
#
# -----
# m::d3;
# a:Vk;
# ****
# fa -> (n <*AM = if 0.65 != 0.0 + 2 && !true && -2.1 <= 234 // 0 == 0.48123 // false then 0.40 % -110 - 0.0 * 2.4 < 32.9 else if false && 0 * 7 % -5 * 3 % -23 - -0 / -0.30 != 0.0 then -6.5 > -3.0 / 6.5>)?;
#  ioY<&P2, *WJu> -> JK # ([$hn = if 0.9 > -70 && !false then 0 + 818.8 * 0 <= -5 // !true] "VP")~;
#
# -----
#
#
# -----
# ::X;
# ::nF;
# T:g;
# ****
# GEek -> [*Y] IjlE2 # kzg <&vD = "d">;
#
# -----
#
#
# -----
# ::K;
# ::Y;
# BP::j8;
# ::W;
# ::z;
# ****
# m<*S> -> ([*X4] q3 <&fqU = "m">)~ # pp # (Y)@;
#
# -----
#
#
# -----
# iS::R;
# ::K9;
# ****
# x4 -> "o" # (qaQ <&eO = 0 <= 3.6>)~ # ([&vu = if !true then -310.4 != 0.8 + 7] "lZ")? # [*G] 95.9 # ([*Ai = 0] L <*ju = if -1 == -0 && -91 % -8 * 0.7354 / -2.23 + 0 != -35.0 + -55.1 then 7.0 * -6.0 * 48.3150 < 0 && -9.0 == -7.6 // 0 >= -0 // 0 % -6.3 != -869 && -3.97 == -78.5 + -7 * 0.5 + -8.88 % -0 && -38 / 0.0 % 0 * -0.6 / 0 <= 3.7 / 0.6 % 0.3 - -218695>)~ # ([*XS] oc)@ # false # ([*Pr] "KZs")@ # ([*yaz8] v <&n9 = u>)@ # [0.7] U2 <*Vw = true> # [0.1] eZ # [*SAhqE] nBnN # QT2 <*GE = O> # true # hDRi;
#
# -----
#
#
# -----
# ::w6;
# ::X6;
# ****
# pAyz7 -> A;
#  lD -> [*uV] J <$R8 = I> # ([*iDo] "V2")~ # [0.8] -2.7;
#
# -----
#
#
# -----
# k -> [0.4] "d" # ([0.4] "b")?;
#  bO<*Xc> -> [*U] -69.0 # ([*C7] wv)~ # true # o;
#  V -> ([$U = -550 == 0.20] q3 <$x = 9>)@ # M;
#
# -----
#
#
# -----
# QL<*k> -> [&e = true] "A6" # ([$nY = 0] z)? # [&pn = if -472 <= -37.60 // false && 5.9 / -0 >= 17 / 0 // false && true then true && false else 0.329 % 0.974 <= 0] -5.83;
#
# -----
#
#
# -----
# X5:Ri;
# d4::K6;
# h1::x;
# ****
# wtZ -> (true)@;
#  q<&aA, *NU> -> (true)@ # ([*ym] k)@;
#
# -----
#
#
# -----
# c9<&O5, *V> -> (BpF <$aM = H>)~ # (-8.7)@ # ([*A] 9)~ # (Jr <&X = 0.10 != 9.2>)?;
#  oIrm7 -> [0.3] Y <&g = if 3336 < 97.33 // false && 0.1 < 4 // 0.4 / 0 / -10 != 9.48 // 0.23 > -3 then 0.60 / -80 != 2 * 384 && 0.0 - -93830 / 0 + 0.19 % 0.0 / 0 + 0 != 0.6 && 8 >= 0 / 0.30 - -3.952 % 1 else -5.0 + -31.0 - 0.64 != 0.56>;
#  Fl5 -> (R3)@ # [*Iuo] -70;
#
# -----
#
#
# -----
# Z<*Dh> -> ([0.5] 5.5)~ # 8;
#
# -----
#
#
# -----
# u:YL;
# ::v;
# ****
# J<*y3> -> (-289.9)~;
#  SC<*flR> -> ([*h] false)?;
#
# -----
#
#
# -----
# IO -> [0.1] g # ([*AG4] tQ3)? # j <*k = 2210.95 < -7 % -0.0 * 0.4>;
#  S<*fVyO> -> 9 # Lev5;
#
# -----
#
#
# -----
# i3 -> ([&M3 = if true then !true && 0 % 0.875 / 49 - 0 % 0.2 < -20 // 0 % 3 == -60 + 6] 0.358)@ # [*b8] E <*bUb = 0.2>;
#
# -----
#
#
# -----
# l<&o, &k, *x> -> [*O5] v <$e = if !true then !true else 0.3 % 0.3 < 0 + 0.9 - 0.16156>;
#
# -----
#
#
# -----
# e:qk;
# gH4::j2;
# r::l;
# ****
# Ee<*lE> -> qCaf # (Nj <&HaCZH = "tt5">)@ # ("W")@ # (-2.8)~ # r5 <*M = -23 + 0 >= 0>;
#
# -----
#
#
# -----
# dY9:gL;
# M5::uE;
# ::uq;
# ::J6;
# ****
# kx<&Y, &zM, *YS> -> 0 # (Q6)~ # ([&C6 = 0 + 168.18 > 240.95 * 0] 0.19)@;
#
# -----
#
#
# -----
# lP<*R1> -> jc;
#
# -----
#
#
# -----
# TBxRHx:DT;
# Iu6:WPkpaH;
# ****
# W4 -> 0.1538;
#  a9 -> ([$A = 3] "LsR")? # ("G")~;
#
# -----
#
#
# -----
# LK<*D> -> ([0.1] "I8")@ # [*vC = c] qBfz <*t = if 4.4 == 9 - 8.5 + -28.5 / -3 % 0 / 0.871 * 4.2 % -0.2 - 0 / 6 / -7.0 + 8 && 0 / 0.3 <= -41.8 / 73 // !true && !false then !true else if 9.7 == 0.3 // 0 - 1670.0 > -6950.4 && -6 + 0.330 + 82.70 - 2232 + 7714 != 0.5 && !true && false then false> # q;
#  OP -> "Il" # ([0.8] "HWI")? # [*M] iyd # [0.6] oa;
#
# -----
#
#
# -----
# V8::aNeLp;
# ::Lp;
# uut:KD7;
# ****
# hu -> [*QI = if 0 / 0.3 != -553.7 && 0.6 > 80.8 / 0.3 + -1 - -1.4 && false then 0 - -3.0 != 0] y # (87)~ # ("S")?;
#
# -----
#
#
# -----
# b -> ([*A = h] YE <&L = 1>)@ # ("m")~;
#  p -> [*s] Q;
#  Z9 -> ([0.9] n)~ # ([$F2 = 0.22] true)@;
#
# -----
#
#
# -----
# a1<*wg> -> (0.81)~ # b <*jn = true>;
#  LS2<*f> -> ([*bb5] false)@;
#
# -----
#
#
# -----
# h9::SB;
# lo:RD;
# ::tb;
# ::Qq8;
# ::I;
# ::Pm;
# ****
# O<*PYUWrbL3> -> (Q7 <*M = false>)@;
#  N -> (0.9)? # ([0.6] A)@;
#  x3<*tT> -> O <&Kei = 974248 < -2.9 * -1.0 * 0 * 7 - -5.6>;
#
# -----
#
#
# -----
# Oehw -> pCP <$wSqm = if 2.130 == -2 && false then -820 % -5 - -5.10 + 15.7 + -2814.7 == 7.80 % 0.7 // -9.3 <= -77 + 96.6 // !false && 8 <= 6.29 % 1 + 0.967 // 0 / 0.6 * -6 == 0.7277 * 26.71 - -0.0>;
#
# -----
#
#
# -----
# v -> "v";
#  S<&mGM, &s, *cl> -> [*jsS] KP <*xLbS = "gI"> # DLOYVU # (0.60)?;
#  zDkD -> ([0.6] Y <*t = true>)? # p <$Iq3 = 8.7>;
#
# -----
#
#
# -----
# s:exd;
# OFV:rKr;
# ****
# TC<&S, *eOt> -> [0.7] 0 # ([*M] 0.5)? # ([&U = 0 == 0] d3 <*J8 = 0 > 0>)@ # ([$MA = if 2.8 == 0 - 0 && -73.20 <= -32 // 68.3 != 1.2 / 7 && -53 >= -0.0 then -3 / -18 * 89.6 > 0 + 0.23 + -7.5743 - 4.6 // -5 <= 4370 % 0 // -64 % 0.8 == 9 && 2.99 > 0.5] 8)~ # [0.2] e3 <&K = -4.1 == -9.8> # [0.2] 0 # ([&w6 = false] true)~;
#
# -----
#
#
# -----
# kF<&lj8, *v> -> (Nqln)? # [*OI] 0.0 # dM <$WZ = if false && false then !true>;
#
# -----
#
#
# -----
# Y -> ([&BXw = "GCe"] -33.5)? # ([&TyC = 0 > 595.8] 58)? # ([0.7] "BA")? # I;
#
# -----
#
#
# -----
# BL -> ([*R7 = if 0.9 != 0.0 // 0 < 1 / 55.9 - 0.3 then 9 * 2 + 0.6 - 0 != 0 % -6.26 % -0 // -21 % -850 + 4 >= -0.9 // false && -3.98 * -20.60 - 0.1 != 0.38 / 0.0 % 0 % 0.7 // !true && !false && -0.39 != -7] -61.0)~;
#  M<&hf, &d, &D, *O> -> [*f] "Fj";
#  nxr7<*J> -> ([*Ty = 3] "Q")@;
#
# -----
#
#
# -----
# Nn<*xlM> -> (Ss)@;
#
# -----
#
#
# -----
# T:AV;
# ::oqe;
# ::m;
# iQzJ2::X8;
# tQ::XQWL;
# Sk::T;
# ::tD;
# ::Doa;
# ::Vd;
# ::sId;
# QC::xR;
# ::C;
# Fz:X;
# ::o;
# E::BJ8;
# ****
# ED -> z <$QX9 = 20> # false # ([*cg] gQ)? # (o3)@ # [*F = false] true # (8)?;
#
# -----
#
#
# -----
# F8::ah;
# g3::ZH;
# Z::d;
# et:BP;
# ****
# vQh<&ej, *hq1> -> (YB)~;
#  Vvg9<&qD, *hLN> -> [0.7] 0 # ([&YD = false] 22)~ # ([0.6] "AO")@;
#
# -----
#
#
# -----
# b:s;
# ::b;
# ::R8;
# ****
# JNS<*m> -> ([0.1] "m5")@;
#
# -----
#
#
# -----
# pdNx:sTup;
# ****
# y3 -> [*T = if -2.1 >= -0 % -290 then 3915660.67 / 36 <= 0] Sj <$sw = false>;
#
# -----
#
#
# -----
# e<&hu, *Qh> -> "Ai" # ("vO5")~ # ([*LGrU] true)@ # ([*cnPNXj] gMyM)~ # ([0.2] s <&c = 2.5 > -0.3>)@ # ([0.7] RUgtwD)?;
#
# -----
#
#
# -----
# I:rXDcYcN;
# ::j;
# Mr:UM;
# ****
# Xc<&ln, &Jw, *Z> -> ([*GX] r <&VZ = 3>)? # (false)?;
#  N -> ([0.2] F8)?;
#  L8 -> [0.8] Q # ([*e = "im"] false)~ # (c)~;
#  G -> (4)? # [0.6] K1 # (n)@;
#
# -----
#
#
# -----
# s9<*g> -> (sYIi <$SUB = 0.76 + -4 > 39>)? # (X4)@;
#
# -----
#
#
# -----
# Q:G;
# er:jC;
# YN:A1;
# ****
# r -> [0.6] W8 <$O9 = if -15.4 <= 34.724 / 0.4 % -71 // -0.66 <= -3830 * 0 - 9.20 * 0.4 - 0.10 then 0.7 < 0 % -80 - 284.5 && 0.2 + 4.6 * -77.5 * 25.2 - 0.60 >= 0 + 0.0> # VmY3 # (-736)@ # (E <*O = if false && 0.2740 - 0 <= 0.15 - 0.0 * -0 then -0.4 >= 0 && -0.6 - 0.3 - 0 + 25.0 - 0 / 10.0 / -9.6 <= -916.3547 && 40 * -9.1 != 24.2340 // !true else 1.7 % 9.20 - 872 == 0 % -52.0 * -0>)@;
#  X<*j> -> ([0.8] ZRm <$F = 2>)@;
#
# -----
#
#
# -----
# D:yZ;
# se::ld;
# ****
# p<*AD> -> ([*YN] f8)@ # [*pG = 0.4] c9 <*d = if true then 0 * 0 >= 0 % -94.1 // 0 - 0 * 8.6 % -0.89 <= -0 / 20 else 0.62 >= 7.3 * 3 * 25.52 * -3.9 - 67>;
#  Zy<&u, *C4> -> ([*Y = "RUR"] 0)?;
#  T -> ([*S9 = "e"] true)?;
#
# -----
#
#
# -----
# m:fJVy7;
# ****
# L2<*i> -> [*MDGx] 7;
#  QV<&W, *O> -> ([*tXtEcP] 0.8)~ # (V <*oY = true>)?;
#
# -----
#
#
# -----
# o4<*x3> -> ([0.2] at)?;
#
# -----
#
#
# -----
# l::C;
# ::HG;
# ::E1;
# H::e7;
# nr::a6;
# G::A4;
# ::M;
# n3::Troc4;
# I::y;
# Vgh::szx;
# ::FfR;
# xs:bNPj;
# n::Coc;
# mTV:H;
# tqf::uPr;
# M::W;
# U:OLr;
# hS:S5;
# ****
# F -> [*gaKo2] n;
#
# -----
#
#
# -----
# Szk<*eFD> -> e # (6)?;
#
# -----
#
#
# -----
# U:kR;
# bR:Co;
# ****
# Q9<&G, &iV4, *uZ4> -> [&x = h] EST # [*rSg] 0.14 # zA <&Vo7 = -850 % 6.0 % 1.7 != -24459>;
#
# -----
#
#
# -----
# S:M1;
# Ga:y;
# ::j;
# ****
# dX<&p3, *I> -> ([0.7] "Vs")?;
#  P8<*z7> -> (false)@ # (true)?;
#  lP<&Q, *Kg8> -> (uLF)~;
#
# -----
#
#
# -----
# kJ -> (J <*Q = 152.396 < 6 / 691.0 + 0>)? # (j <&mT = 2853 % 0 + -7.5 >= 992>)@;
#
# -----
#
#
# -----
# MA -> true;
#
# -----

# %%
print("Finished Running")
# Out:
# Finished Running
